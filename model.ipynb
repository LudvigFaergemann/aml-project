# %%
# Try to import ALL packages. If any are missing, install them all.
try:
    import pandas as pd
    import numpy as np
    import xlrd
    import openpyxl
    import nbstripout
except ImportError:
    print("Missing packages detected. Installing...")
    # Install pandas and numpy along with the others
    # %pip install pandas numpy xlrd openpyxl nbstripout -q
    print("Installation complete. RESTART(ING) KERNEL NOW.")

# Re-import after installation
import pandas as pd
import numpy as np

# LOAD DATA
# Added header=1 to fix the double-header issue
df_data = pd.read_excel('./data/default of credit card clients.xls', header=1)

print(df_data.head())
