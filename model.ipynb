# %%
import pandas as pd
import numpy as np

#INSTALL THE REQUIRED PACKAGE
# !pip install xlrd
# !pip install nbstripout

# LOAD DATA
df_data = pd.read_excel('./data/default of credit card clients.xls')

print(df_data.head())
